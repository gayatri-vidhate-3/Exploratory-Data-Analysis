# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('New_York_Taxi_Trip_dataSet.csv')

# %%
df
# Out:
#               id  vendor_id pickup_datetime dropoff_datetime  passenger_count  \
# 0      id0190469          2   1/1/2016 0:00    1/1/2016 0:14                5
# 1      id1665586          1   1/1/2016 0:00    1/1/2016 0:22                1
# 2      id1078247          2   1/1/2016 0:01    1/1/2016 0:03                1
# 3      id3609443          1   1/1/2016 0:01    1/1/2016 0:21                2
# 4      id3888279          1   1/1/2016 0:01    1/1/2016 0:05                1
# ...          ...        ...             ...              ...              ...
# 39391  id2018916          2  1/8/2016 21:56   1/8/2016 21:59                5
# 39392  id3400877          2  1/8/2016 21:56   1/8/2016 22:01                1
# 39393  id3324326          2  1/8/2016 21:56   1/8/2016 22:05                1
# 39394  id3410388          2  1/8/2016 21:56   1/8/2016 21:58                1
# 39395  id0044708          2  1/8/2016 21:56   1/8/2016 22:14                1
#
# ...

# %%
df.shape
# Out:
# (39396, 14)

# %%
df.describe()
# Out:
#           vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  39396.000000     39396.000000      39396.000000     39396.000000
# mean       1.540512         1.691669        -73.971934        40.750858
# std        0.498362         1.332440          0.041576         0.040643
# min        1.000000         0.000000        -74.345078        35.081532
# 25%        1.000000         1.000000        -73.991318        40.737885
# 50%        2.000000         1.000000        -73.981133        40.754929
# 75%        2.000000         2.000000        -73.966316        40.768787
# max        2.000000         8.000000        -71.799896        41.023983
#
#        dropoff_longitude  dropoff_latitude   gc_distance  trip_duration  \
# count       39396.000000      39396.000000  39396.000000   3.939600e+04
# mean          -73.973048         40.752142      2.166888   9.745813e+02
# std             0.045388          0.032743      3.769393   1.524926e+04
# ...

# %%
# Statistical description of dataframe was returned with the respective passed percentiles. 
# For the columns with strings, NaN was returned for numeric operations.


df.describe(include='all')
# Out:
#                id     vendor_id pickup_datetime dropoff_datetime  \
# count       39396  39396.000000           39396            39396
# unique      39396           NaN            9934             9949
# top     id0190469           NaN  1/7/2016 18:53    1/1/2016 1:25
# freq            1           NaN              16               16
# mean          NaN      1.540512             NaN              NaN
# std           NaN      0.498362             NaN              NaN
# min           NaN      1.000000             NaN              NaN
# 25%           NaN      1.000000             NaN              NaN
# 50%           NaN      2.000000             NaN              NaN
# 75%           NaN      2.000000             NaN              NaN
# max           NaN      2.000000             NaN              NaN
#
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count      39396.000000      39396.000000     39396.000000       39396.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39396 entries, 0 to 39395
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  39396 non-null  object
#  1   vendor_id           39396 non-null  int64
#  2   pickup_datetime     39396 non-null  object
#  3   dropoff_datetime    39396 non-null  object
#  4   passenger_count     39396 non-null  int64
#  5   pickup_longitude    39396 non-null  float64
#  6   pickup_latitude     39396 non-null  float64
#  7   dropoff_longitude   39396 non-null  float64
#  8   dropoff_latitude    39396 non-null  float64
#  9   store_and_fwd_flag  39396 non-null  object
#  10  gc_distance         39396 non-null  float64
#  11  trip_duration       39396 non-null  int64
#  12  google_distance     38837 non-null  float64
#  13  google_duration     38837 non-null  float64
# dtypes: float64(7), int64(3), object(4)
# memory usage: 4.2+ MB

# %%
df.isna().sum()
# Out:
# id                      0
# vendor_id               0
# pickup_datetime         0
# dropoff_datetime        0
# passenger_count         0
# pickup_longitude        0
# pickup_latitude         0
# dropoff_longitude       0
# dropoff_latitude        0
# store_and_fwd_flag      0
# gc_distance             0
# trip_duration           0
# google_distance       559
# google_duration       559
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# dropoff_datetime      0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# gc_distance           0
# trip_duration         0
# google_distance       0
# google_duration       0
# dtype: int64

# %%
df.shape
# Out:
# (38837, 14)

# %%
df.dtypes
# Out:
# id                            object
# vendor_id                      int64
# pickup_datetime       datetime64[ns]
# dropoff_datetime      datetime64[ns]
# passenger_count                int64
# pickup_longitude             float64
# pickup_latitude              float64
# dropoff_longitude            float64
# dropoff_latitude             float64
# store_and_fwd_flag            object
# gc_distance                  float64
# trip_duration                  int64
# google_distance              float64
# google_duration              float64
# dtype: object

# %%
df.nunique()
# Out:
# id                    38837
# vendor_id                 2
# pickup_datetime        9819
# dropoff_datetime       9854
# passenger_count           8
# pickup_longitude      10348
# pickup_latitude       18222
# dropoff_longitude     11715
# dropoff_latitude      20127
# store_and_fwd_flag        2
# gc_distance           38670
# trip_duration          2929
# google_distance       11985
# google_duration        2703
# dtype: int64

# %%
df.head(3)
# Out:
#           id  vendor_id pickup_datetime dropoff_datetime  passenger_count  \
# 0  id0190469          2   1/1/2016 0:00    1/1/2016 0:14                5
# 1  id1665586          1   1/1/2016 0:00    1/1/2016 0:22                1
# 2  id1078247          2   1/1/2016 0:01    1/1/2016 0:03                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.981743        40.719158         -73.938828         40.829182
# 1        -73.985085        40.747166         -73.958038         40.717491
# 2        -73.973335        40.764072         -73.974854         40.761734
#
#   store_and_fwd_flag  gc_distance  trip_duration  google_distance  \
# 0                  N     7.928830            849          15309.0
# 1                  N     2.492482           1294           9970.0
# 2                  N     0.180099            114            289.0
#
#    google_duration
# 0           1109.0
# 1           1277.0
# 2             79.0

# %%
non_num_cols=['id','pickup_datetime','dropoff_datetime','store_and_fwd_flag']
print(df[non_num_cols].count())
# Out:
# id                    38837
# pickup_datetime       38837
# dropoff_datetime      38837
# store_and_fwd_flag    38837
# dtype: int64

# %%
# pickup_datetime and dropoff_datetime are now converted to datetime format

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
df['dropoff_datetime']=pd.to_datetime(df['dropoff_datetime'])

# %%
df['pickup_datetime']
# Out:
# 0       2016-01-01 00:00:00
# 1       2016-01-01 00:00:00
# 2       2016-01-01 00:01:00
# 3       2016-01-01 00:01:00
# 4       2016-01-01 00:01:00
#                 ...
# 39391   2016-01-08 21:56:00
# 39392   2016-01-08 21:56:00
# 39393   2016-01-08 21:56:00
# 39394   2016-01-08 21:56:00
# 39395   2016-01-08 21:56:00
# Name: pickup_datetime, Length: 38837, dtype: datetime64[ns]

# %%
df['dropoff_datetime']
# Out:
# 0       2016-01-01 00:14:00
# 1       2016-01-01 00:22:00
# 2       2016-01-01 00:03:00
# 3       2016-01-01 00:21:00
# 4       2016-01-01 00:05:00
#                 ...
# 39391   2016-01-08 21:59:00
# 39392   2016-01-08 22:01:00
# 39393   2016-01-08 22:05:00
# 39394   2016-01-08 21:58:00
# 39395   2016-01-08 22:14:00
# Name: dropoff_datetime, Length: 38837, dtype: datetime64[ns]

# %% [markdown]
# #Univariate Analysis

# %%
sns.countplot(df['passenger_count'])
# Out:
# C:\Users\Gayatri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='passenger_count', ylabel='count'>

# %%
df['store_and_fwd_flag'].value_counts()
# Out:
# N    38612
# Y      225
# Name: store_and_fwd_flag, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'gc_distance', 'trip_duration', 'google_distance', 'google_duration'],
#       dtype='object')

# %%
df
# Out:
#               id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0      id0190469          2 2016-01-01 00:00:00 2016-01-01 00:14:00
# 1      id1665586          1 2016-01-01 00:00:00 2016-01-01 00:22:00
# 2      id1078247          2 2016-01-01 00:01:00 2016-01-01 00:03:00
# 3      id3609443          1 2016-01-01 00:01:00 2016-01-01 00:21:00
# 4      id3888279          1 2016-01-01 00:01:00 2016-01-01 00:05:00
# ...          ...        ...                 ...                 ...
# 39391  id2018916          2 2016-01-08 21:56:00 2016-01-08 21:59:00
# 39392  id3400877          2 2016-01-08 21:56:00 2016-01-08 22:01:00
# 39393  id3324326          2 2016-01-08 21:56:00 2016-01-08 22:05:00
# 39394  id3410388          2 2016-01-08 21:56:00 2016-01-08 21:58:00
# 39395  id0044708          2 2016-01-08 21:56:00 2016-01-08 22:14:00
#
#        passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
sns.catplot('store_and_fwd_flag','google_distance',data = df)
# Out:
# C:\Users\Gayatri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot('passenger_count','google_distance',data = df)
# Out:
# C:\Users\Gayatri\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
